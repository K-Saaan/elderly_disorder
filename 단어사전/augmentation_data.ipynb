# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import json
from kiwipiepy import Kiwi
from collections import Counter
import tqdm
import os

# %%
os.getcwd()
# Out:
# '/Users/gimsan/Documents/GitHub/elderly_disorder/단어사전'

# %%
data = pd.read_csv('../data/노년층 대상 감성 분류 모델/train.csv')

# %%
data.head()
# Out:
#    성별 감정_대분류                                          사람문장1
# 0  남성     불안        당뇨랑 합병증 때문에 먹어야 할 약이 열 가지가 넘어가니까 스트레스야.  \
# 1  남성     기쁨  재취업이 돼서 받게 된 첫 월급으로 온 가족이 외식을 할 예정이야. 너무 행복해.
# 2  여성     기쁨                   빚을 드디어 다 갚게 되어서 이제야 안도감이 들어.
# 3  남성     분노                                 이제 돈이라면 지긋지긋해.
# 4  여성     슬픔                                   친구 때문에 눈물 나.
#
#                            시스템응답1
# 0              약 종류가 많아 번거로우시겠어요.  \
# 1         재취업 후 첫 월급이라 정말 기쁘시겠어요.
# 2  기분 좋으시겠어요. 앞으로는 어떻게 하실 생각이신가요?
# 3                     무슨 일 있으셨나요?
# 4     친구 때문에 눈물이 나시는군요. 무슨 일이세요?
#
#                                                사람문장2
# 0                        건강할 때 관리 좀 잘할걸 하는 생각이 들더라고.  \
# 1  퇴직 후 다시는 돈을 못 벌 줄 알았는데 이렇게 월급으로 가족에게 맛있는 밥을 살 ...
# 2                  빚도 다 갚았으니 당분간은 아무 생각도 안 하며 살고 싶어.
# 3                       나이가 예순이 넘으니 돈이 나갈 데도 많고 힘드네.
# 4                                   내 친구가 나한테 거짓말했어.
#
# ...

# %%
data.fillna('', inplace=True)

# %%
data['사람문장'] = data['사람문장1'] + data['사람문장2'] + data['사람문장3'] + data['사람문장4']

# %%
data.head()
# Out:
#    성별 감정_대분류                                          사람문장1
# 0  남성     불안        당뇨랑 합병증 때문에 먹어야 할 약이 열 가지가 넘어가니까 스트레스야.  \
# 1  남성     기쁨  재취업이 돼서 받게 된 첫 월급으로 온 가족이 외식을 할 예정이야. 너무 행복해.
# 2  여성     기쁨                   빚을 드디어 다 갚게 되어서 이제야 안도감이 들어.
# 3  남성     분노                                 이제 돈이라면 지긋지긋해.
# 4  여성     슬픔                                   친구 때문에 눈물 나.
#
#                            시스템응답1
# 0              약 종류가 많아 번거로우시겠어요.  \
# 1         재취업 후 첫 월급이라 정말 기쁘시겠어요.
# 2  기분 좋으시겠어요. 앞으로는 어떻게 하실 생각이신가요?
# 3                     무슨 일 있으셨나요?
# 4     친구 때문에 눈물이 나시는군요. 무슨 일이세요?
#
#                                                사람문장2
# 0                        건강할 때 관리 좀 잘할걸 하는 생각이 들더라고.  \
# 1  퇴직 후 다시는 돈을 못 벌 줄 알았는데 이렇게 월급으로 가족에게 맛있는 밥을 살 ...
# 2                  빚도 다 갚았으니 당분간은 아무 생각도 안 하며 살고 싶어.
# 3                       나이가 예순이 넘으니 돈이 나갈 데도 많고 힘드네.
# 4                                   내 친구가 나한테 거짓말했어.
#
# ...

# %%
aug_df = data[['감정_대분류', '사람문장']]
aug_df.head()
# Out:
#   감정_대분류                                               사람문장
# 0     불안  당뇨랑 합병증 때문에 먹어야 할 약이 열 가지가 넘어가니까 스트레스야.건강할 때 관...
# 1     기쁨  재취업이 돼서 받게 된 첫 월급으로 온 가족이 외식을 할 예정이야. 너무 행복해.퇴...
# 2     기쁨  빚을 드디어 다 갚게 되어서 이제야 안도감이 들어.빚도 다 갚았으니 당분간은 아무 ...
# 3     분노         이제 돈이라면 지긋지긋해.나이가 예순이 넘으니 돈이 나갈 데도 많고 힘드네.
# 4     슬픔                       친구 때문에 눈물 나.내 친구가 나한테 거짓말했어.

# %%
aug_df.to_csv('../aug_df.csv', index=False)
