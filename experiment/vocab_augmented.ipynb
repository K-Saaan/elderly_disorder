# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install -U sentence-transformers
# !pip install kiwipiepy
# !pip install ipython-autotime
# Out:
# Collecting sentence-transformers
#   Downloading sentence_transformers-3.0.1-py3-none-any.whl (227 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 227.1/227.1 kB 2.2 MB/s eta 0:00:00
# Requirement already satisfied: transformers<5.0.0,>=4.34.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (4.41.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (4.66.4)
# Requirement already satisfied: torch>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (2.3.0+cu121)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (1.25.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (1.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (1.11.4)
# Requirement already satisfied: huggingface-hub>=0.15.1 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (0.23.3)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (9.4.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers) (3.14.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers) (2023.6.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers) (6.0.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers) (2.31.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers) (4.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (1.12.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (3.1.4)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch>=1.11.0->sentence-transformers)
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch>=1.11.0->sentence-transformers)
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch>=1.11.0->sentence-transformers)
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch>=1.11.0->sentence-transformers)
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch>=1.11.0->sentence-transformers)
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch>=1.11.0->sentence-transformers)
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch>=1.11.0->sentence-transformers)
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch>=1.11.0->sentence-transformers)
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch>=1.11.0->sentence-transformers)
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# Collecting nvidia-nccl-cu12==2.20.5 (from torch>=1.11.0->sentence-transformers)
#   Using cached nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl (176.2 MB)
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch>=1.11.0->sentence-transformers)
#   Using cached nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
# Requirement already satisfied: triton==2.3.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (2.3.0)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.11.0->sentence-transformers)
#   Downloading nvidia_nvjitlink_cu12-12.5.40-py3-none-manylinux2014_x86_64.whl (21.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.3/21.3 MB 51.3 MB/s eta 0:00:00
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.34.0->sentence-transformers) (2024.5.15)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.34.0->sentence-transformers) (0.19.1)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.34.0->sentence-transformers) (0.4.3)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->sentence-transformers) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->sentence-transformers) (3.5.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.11.0->sentence-transformers) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers) (2024.6.2)
# Requirement already satisfied: mpmath<1.4.0,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.11.0->sentence-transformers) (1.3.0)
# Installing collected packages: nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, sentence-transformers
# Successfully installed nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.20.5 nvidia-nvjitlink-cu12-12.5.40 nvidia-nvtx-cu12-12.1.105 sentence-transformers-3.0.1
# Collecting kiwipiepy
#   Downloading kiwipiepy-0.17.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 10.4 MB/s eta 0:00:00
# Collecting kiwipiepy-model<0.18,>=0.17 (from kiwipiepy)
#   Downloading kiwipiepy_model-0.17.0.tar.gz (34.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34.7/34.7 MB 11.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from kiwipiepy) (1.25.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from kiwipiepy) (4.66.4)
# Building wheels for collected packages: kiwipiepy-model
#   Building wheel for kiwipiepy-model (setup.py) ... done
#   Created wheel for kiwipiepy-model: filename=kiwipiepy_model-0.17.0-py3-none-any.whl size=34845033 sha256=291e89728351cdc4987f1af460e8d2621c42ea1c652f999aee56c057bc09a590
#   Stored in directory: /root/.cache/pip/wheels/90/bb/ae/15e1cf26d17183040bac268fbf8d1ca1f45f7f4daa0fb76b91
# Successfully built kiwipiepy-model
# Installing collected packages: kiwipiepy-model, kiwipiepy
# Successfully installed kiwipiepy-0.17.1 kiwipiepy-model-0.17.0
# Collecting ipython-autotime
#   Downloading ipython_autotime-0.3.2-py2.py3-none-any.whl (7.0 kB)
# Requirement already satisfied: ipython in /usr/local/lib/python3.10/dist-packages (from ipython-autotime) (7.34.0)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.10/dist-packages (from ipython->ipython-autotime) (67.7.2)
# Collecting jedi>=0.16 (from ipython->ipython-autotime)
#   Downloading jedi-0.19.1-py2.py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 7.4 MB/s eta 0:00:00
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from ipython->ipython-autotime) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.10/dist-packages (from ipython->ipython-autotime) (0.7.5)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.10/dist-packages (from ipython->ipython-autotime) (5.7.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from ipython->ipython-autotime) (3.0.47)
# Requirement already satisfied: pygments in /usr/local/lib/python3.10/dist-packages (from ipython->ipython-autotime) (2.16.1)
# Requirement already satisfied: backcall in /usr/local/lib/python3.10/dist-packages (from ipython->ipython-autotime) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.10/dist-packages (from ipython->ipython-autotime) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/dist-packages (from ipython->ipython-autotime) (4.9.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from jedi>=0.16->ipython->ipython-autotime) (0.8.4)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.10/dist-packages (from pexpect>4.3->ipython->ipython-autotime) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->ipython-autotime) (0.2.13)
# Installing collected packages: jedi, ipython-autotime
# Successfully installed ipython-autotime-0.3.2 jedi-0.19.1

# %%
# 셀 별로 러닝타임 측정
# %load_ext autotime
# Out:
# time: 311 µs (started: 2024-06-12 18:29:06 +00:00)

# %%
# %cd /content/drive/MyDrive/Colab_Notebooks/elderly_disorder/experiment
# Out:
# /content/drive/MyDrive/Colab_Notebooks/elderly_disorder/experiment
# time: 3.87 ms (started: 2024-06-12 18:29:06 +00:00)

# %%
import pandas as pd
import numpy as np
import torch
import re
import os
import ast
from kiwipiepy import Kiwi
from sentence_transformers import SentenceTransformer, util

# CUDA 캐시 지우기
torch.cuda.empty_cache()
print(torch.cuda.is_available())
print(torch.cuda.get_device_name(0))

# 각종 모델 정의
kiwi = Kiwi()  # Kiwi 초기화
word_vectors = SentenceTransformer('paraphrase-MiniLM-L6-v2')  # 정신질환 특화 Sentence-Transformer 모델 로드

# 파일 로드
file_path = '../data/vocab_augmented.csv'
vocab_df = pd.read_csv(file_path)
# 열의 모든 데이터를 리스트로 변환
vocab_df['tokens'] = vocab_df['tokens'].apply(ast.literal_eval)

# 새로운 단어사전 파일 로드
new_vocab_path = '../data/new_vocab.csv'
new_vocab_df = pd.read_csv(new_vocab_path)

# 데이터 확인
vocab_df.head()
# Out:
# /usr/local/lib/python3.10/dist-packages/sentence_transformers/cross_encoder/CrossEncoder.py:11: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm, trange
# True
# Tesla T4
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/229 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/122 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/3.73k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# config.json:   0%|          | 0.00/629 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/314 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
#                        mental_disorder  \
# 0        obsessive_compulsive_disorder
# 1  PTSD(posttraumatic_stress_disorder)
# 2        paranoid_personality_disorder
# 3                                 ADHD
# 4                     bipolar_disorder
#
#                                               tokens
# 0  [예방, 고통, 사건, 이상, 중요, 강박, 물질, 활동, 반응, 현실, 억제, 효...
# 1  [침해, 이상, 사건, 고통, 중요, 물질, 반응, 부정, 장기간, 가족, 효과, ...
# 2  [사건, 착취, 사유, 발언, 기인, 효과, 이용, 명성, 위협, 두려움, 과정, ...
# 3  [침해, 주의, 학업, 활동, 집중력, 응답, 약속, 사항, 소지품, 과제, 정리,...
# 4  [주의, 고통, 중요, 활동, 과민, 과대, 감소, 부주의, 자존감, 과대망상, 구...
# time: 22.5 s (started: 2024-06-12 18:29:06 +00:00)

# %%
'''
유사한 단어 찾기 및 단어사전에 추가
※문제점: 한자가 나오거나 너무 동떨어진 단어 추가 발생 => 한자 정규식 확인 및 유사도 일정 수치 이하 탈락시킴
'''

def is_hanja(word):
    # 한자 범위를 정규 표현식으로 정의
    hanja_range = re.compile(r'[\u4e00-\u9fff]+')
    return hanja_range.search(word) is not None

def augment_dictionary_with_similar_words(model, word_dictionary, new_vocab_tokens, top_n=3, similarity_threshold=0.7):
    augmented_dictionary = {}
    new_tokens_added = {}
    token_similar_words_added = {}  # 어떤 토큰에서 어떤 유사한 단어들이 추가되었는지 기록

    existing_tokens = set([token for sublist in word_dictionary['tokens'] for token in sublist])

    for disorder, tokens in zip(word_dictionary["mental_disorder"], word_dictionary["tokens"]):
        augmented_tokens = tokens.copy()
        new_tokens_for_disorder = []
        token_similar_words = {}  # 현재 질환에 대해 토큰별 추가된 유사한 단어들

        target_tags = ['NNG', 'NNP', 'NR', 'NP', 'VCN', 'MAG', 'XPN']

        for token in tokens:
            try:
                token_embedding = model.encode(token, convert_to_tensor=True)
                # 새로운 단어에 대해 임베딩 생성
                new_vocab_embeddings = model.encode(new_vocab_tokens, convert_to_tensor=True)
                cos_sim = util.pytorch_cos_sim(token_embedding, new_vocab_embeddings)
                similar_words_idx = torch.topk(cos_sim, top_n, largest=True).indices[0]
                similar_words = [new_vocab_tokens[idx] for idx in similar_words_idx]

                similar_words_added = []

                for idx, word in zip(similar_words_idx, similar_words):
                    if cos_sim[0][idx].item() >= similarity_threshold and not is_hanja(word) and word not in existing_tokens:
                        analyzed = kiwi.analyze(word)[0][0]  # 첫 번째 분석 결과
                        word_tags = [morph.tag for morph in analyzed]  # 형태소 태그 추출

                        # target_tags에 포함된 태그가 있는지 확인
                        if any(tag in target_tags for tag in word_tags) and word not in augmented_tokens:
                            augmented_tokens.append(word)
                            new_tokens_for_disorder.append(word)
                            similar_words_added.append(word)
                            existing_tokens.add(word)

                if similar_words_added:
                    token_similar_words[token] = similar_words_added

            except KeyError:
                continue

        augmented_dictionary[disorder] = augmented_tokens
        new_tokens_added[disorder] = new_tokens_for_disorder
        token_similar_words_added[disorder] = token_similar_words

    return augmented_dictionary, new_tokens_added, token_similar_words_added

# 새로운 단어사전에서 모든 토큰 추출
new_vocab_tokens = new_vocab_df['Word'].tolist()

############## 파라미터 수정
augmented_filtered_token_disorder, new_tokens_added, token_similar_words_added = augment_dictionary_with_similar_words(word_vectors, vocab_df, new_vocab_tokens, top_n=5, similarity_threshold=0.65)

# 어떤 토큰에서 어떤 유사한 단어들이 추가되었는지 출력
for disorder, tokens_info in token_similar_words_added.items():
    print(f"Disorder: {disorder}")
    for token, similar_words in tokens_info.items():
        print(f"  Token '{token}' added similar words: {similar_words}")

print()
# Out:
# Disorder: obsessive_compulsive_disorder
#   Token '예방' added similar words: ['이제서야', '끊임없이', '상관없이', '슈퍼마켓', '생계유지']
#   Token '고통' added similar words: ['공통', '공로', '공모', '공고']
#   Token '사건' added similar words: ['사전', '선자', '선사', '선고']
#   Token '이상' added similar words: ['이장', '인상', '이랑', '이성']
#   Token '중요' added similar words: ['주역', '주원', '주연', '중역']
#   Token '강박' added similar words: ['각방', '각각', '가방', '극장']
#   Token '물질' added similar words: ['물기', '미술', '비주얼', '불길']
#   Token '활동' added similar words: ['혈당', '합동', '출동', '홀랑']
#   Token '반응' added similar words: ['방안', '반항', '방어', '반영']
#   Token '현실' added similar words: ['행실', '병실', '분실']
#   Token '억제' added similar words: ['언제', '업적', '어제', '억척']
#   Token '효과' added similar words: ['효녀', '협의', '확', '화제']
#   Token '충동' added similar words: ['충당', '명동', '충족']
#   Token '하루' added similar words: ['후자', '하마', '합주']
#   Token '감소' added similar words: ['고삼', '감사', '감성', '감시']
#   Token '설명' added similar words: ['설령', '성별', '선명', '술병']
#   Token '정리' added similar words: ['정치', '정비', '정기', '정지']
#   Token '불안' added similar words: ['불만', '발인', '분간']
#   Token '기간' added similar words: ['기만', '기강', '기한', '기반']
#   Token '무시' added similar words: ['무기', '무지', '민수', '무식']
#   Token '생리' added similar words: ['생기', '생시', '성비', '사칭']
#   Token '재발' added similar words: ['제발', '절차', '절하']
#   Token '적용' added similar words: ['적응', '정액', '전역']
#   Token '초래' added similar words: ['초대', '차로', '체조']
#   Token '손상' added similar words: ['상상', '선상', '신상', '상소']
#   Token '중화' added similar words: ['정화', '주행', '정황', '주정']
#   Token '엄격' added similar words: ['염색', '어묵', '엄청']
#   Token '유발' added similar words: ['유방', '월차', '우발', '알바']
#   Token '단어' added similar words: ['대안', '단원', '답안']
#   Token '조용히' added similar words: ['종교인', '지현이', '종아리', '지팡이']
#   Token '영역' added similar words: ['용역', '영영', '역경', '영국']
#   Token '임상' added similar words: ['입상', '입장']
#   Token '의학' added similar words: ['유학', '어학', '의혹', '의탁']
#   Token '연결' added similar words: ['완결', '열병', '연출', '열정']
#   Token '장애' added similar words: ['재앙', '장어', '장래', '잔액']
#   Token '생각' added similar words: ['색상', '상극', '상책', '상복']
#   Token '시도' added similar words: ['심도', '시조', '십오', '소리']
#   Token '개인' added similar words: ['거인', '기안', '개진', '개개인']
#   Token '시간' added similar words: ['신자', '사진', '신사', '시한']
#   Token '기도' added similar words: ['기호', '기록', '기초', '기복']
#   Token '대부분' added similar words: ['덕분', '멘붕', '둔부']
#   Token '상태' added similar words: ['상대', '사택', '사탕']
#   Token '기능' added similar words: ['기증', '기승', '기흉', '기둥']
#   Token '소요' added similar words: ['소유', '소아', '소원', '수포', '소용']
#   Token '반복' added similar words: ['반박', '번복', '한복', '박봉']
#   Token '이미지' added similar words: ['이주민', '일자리', '이기주', '일진']
#   Token '대응' added similar words: ['대용', '대등', '등원', '댄스']
#   Token '사고' added similar words: ['사모', '사가', '사도']
#   Token '행동' added similar words: ['혼동', '행복']
#   Token '지속' added similar words: ['직속', '종식', '지식']
#   Token '규칙' added similar words: ['기류', '기척', '교직', '교촌']
#   Token '경험' added similar words: ['경품', '관점', '검정', '검증']
#   Token '관념' added similar words: ['금년', '개념']
#   Token '분명히' added similar words: ['불치병', '변변히', '변화무쌍', '병문안']
#   Token '목표' added similar words: ['모교', '모피', '폭력']
#   Token '정신' added similar words: ['전신', '종신', '정진', '직선']
#   Token '증상' added similar words: ['정상', '장성', '정당', '정산']
#   Token '확인' added similar words: ['확진', '확연히', '행인']
#   Token '방해' added similar words: ['항해', '발행', '배당']
#   Token '직업' added similar words: ['적립', '픽업', '정립']
#   Token '상황' added similar words: ['상환', '상관', '상충', '방황']
#   Token '소모' added similar words: ['.소모', '수모', '수고']
#   Token '동안' added similar words: ['동산', '당신', '단종', '동반']
#   Token '수행' added similar words: ['수생', '선행', '수능', '수긍']
#   Token '침입' added similar words: ['출입', '칠십', '매입']
#   Token '숙어' added similar words: ['수억', '수액', '성우', '수석', '성의']
#   Token '내내' added similar words: ['내재', '내규', '내주']
# Disorder: PTSD(posttraumatic_stress_disorder)
#   Token '침해' added similar words: ['침대', '참치', '침체']
#   Token '부정' added similar words: ['부전', '번주', '분명', '부적']
#   Token '장기간' added similar words: ['지방간', '장신구', '지상권']
#   Token '가족' added similar words: ['고작', '가속', '가혹', '각자']
#   Token '사항' added similar words: ['상하', '사랑', '사장', '사방']
#   Token '변화' added similar words: ['병환', '변형', '완화']
#   Token '죽음' added similar words: ['적금', '작품', '잡음', '중점']
#   Token '내용' added similar words: ['내역', '내원', '내숭', '내정']
#   Token '목격' added similar words: ['명목', '목적', '명복', '목청']
#   Token '직접' added similar words: ['직급']
#   Token '측면' added similar words: ['청력', '측정', '천국', '체면']
#   Token '부상' added similar words: ['부장', '부산', '밥상']
#   Token '인지' added similar words: ['인기', '이민', '일지']
#   Token '심리' added similar words: ['심기', '실리', '신비']
#   Token '관련' added similar words: ['과연', '관건', '관청']
#   Token '구성원' added similar words: ['국영수', '공무원', '고용주', '국제선']
#   Token '방식' added similar words: ['방직', '상식', '빈속', '복싱']
#   Token '해리' added similar words: ['해지', '허리', '해로', '허비', '미래']
#   Token '초과' added similar words: ['치과', '포교', '초근']
#   Token '노출' added similar words: ['나물', '도출', '널리', '날로']
#   Token '자발' added similar words: ['절반']
#   Token '기억' added similar words: ['기역', '기적', '곤욕']
#   Token '기분' added similar words: ['기준', '기부', '국비']
#   Token '친구' added similar words: ['추진', '친우', '치중', '친부']
#   Token '상징' added similar words: ['식장', '송장', '신장', '상종', '성징']
#   Token '극단' added similar words: ['근막', '금단', '그다지', '간극']
#   Token '상해' added similar words: ['산행', '산재']
#   Token '사람' added similar words: ['삼자', '수감', '삼수', '새삼']
#   Token '각성' added similar words: ['격상', '각종', '공석']
#   Token '세부' added similar words: ['세수', '수제', '세분', '수법']
#   Token '심각' added similar words: ['식감', '시각', '심장', '시국', '시작']
#   Token '성폭력' added similar words: ['성폭행', '원동력', '통찰력', '가족력']
#   Token '실제' added similar words: ['실체', '시제', '시절', '실내']
#   Token '자극' added similar words: ['즉각', '자국', '자각', '작가']
#   Token '단서' added similar words: ['답사', '당선', '단가']
#   Token '내부' added similar words: ['내수', '내과']
#   Token '발생' added similar words: ['배상', '발송', '발간']
# Disorder: paranoid_personality_disorder
#   Token '사유' added similar words: ['.사유', '사규', '사류']
#   Token '발언' added similar words: ['발전']
#   Token '기인' added similar words: ['고인', '기운', '구인']
#   Token '이용' added similar words: ['이왕', '왕이', '일용', '임용']
#   Token '명성' added similar words: ['형성', '명령', '충성', '명소']
#   Token '두려움' added similar words: ['두루두루', '후두염', '움추러']
#   Token '과정' added similar words: ['교정', '광주']
#   Token '용서' added similar words: ['여성', '원서', '용어', '요구서']
#   Token '동료' added similar words: ['도용', '동력', '동의']
#   Token '사용' added similar words: ['상여', '상의', '사연']
#   Token '타인' added similar words: ['타운', '타이어', '탕진', '티오']
#   Token '정보' added similar words: ['주봉', '전보', '정도', '접종']
#   Token '배우자' added similar words: ['반려자', '백만']
#   Token '악의' added similar words: ['육아', '의아', '워낙']
#   Token '불신' added similar words: ['출신', '비수기']
#   Token '분열증' added similar words: ['우울증', '우왕좌왕', '분풀이']
#   Token '해석' added similar words: ['행세', '행색', '백색']
#   Token '정신병' added similar words: ['정신병자', '정신력', '성인병', '중장년']
#   Token '충실' added similar words: ['평일']
#   Token '비하' added similar words: ['비자', '바디', '바지', '반지']
#   Token '양극성 장애' added similar words: ['난생', '장애자', '여자애']
#   Token '충성심' added similar words: ['평정심', '동경심', '동정심', '방석집']
#   Token '우울' added similar words: ['우물', '억울', '울분', '울음']
#   Token '비밀' added similar words: ['빌미', '비닐', '빌빌', '비굴']
#   Token '공격' added similar words: ['공경', '공적', '경고']
#   Token '신속' added similar words: ['신식', '소식', '손익', '실속']
#   Token '반격' added similar words: ['본격', '방역', '반경', '방석', '부각']
#   Token '불리' added similar words: ['불치', '부질', '불로']
#   Token '동기' added similar words: ['동지', '동시', '동이', '봉지']
#   Token '성인' added similar words: ['승인', '신앙', '신용', '승진']
#   Token '조현병' added similar words: ['자명종', '정신과']
#   Token '근거' added similar words: ['그전', '근교', '급전']
#   Token '부당' added similar words: ['분가', '밤중']
#   Token '성격' added similar words: ['성적', '성경', '성병', '성숙']
#   Token '경멸' added similar words: ['경철', '결별', '결정', '결렬']
#   Token '특징' added similar words: ['팀장', '특강', '통증', '특기']
#   Token '초기' added similar words: ['.초기', '차기', '포기', '치기']
#   Token '파트너' added similar words: ['펀트', '포스터', '파업']
#   Token '정절' added similar words: ['중절', '전철', '조절', '저질']
#   Token '의심' added similar words: ['욕심', '입금', '의구심', '입담']
#   Token '의미' added similar words: ['의리', '의지', '의기', '유미']
#   Token '평판' added similar words: ['평탄', '판명', '평안', '단편']
#   Token '자신' added similar words: ['지간', '자진', '지사', '진가']
#   Token '경시' added similar words: ['경기', '경지', '경신', '기성']
#   Token '원한' added similar words: ['원본', '여하튼', '연하', '운반']
#   Token '모욕' added similar words: ['목욕', '미역', '먹이', '미옥']
#   Token '특성' added similar words: ['특정', '특근', '특권']
# Disorder: ADHD
#   Token '주의' added similar words: ['좌우', '주거', '주눅']
#   Token '학업' added similar words: ['억압', '학급', '학습', '확답']
#   Token '집중력' added similar words: ['집구석', '직업병', '중국집', '집중도']
#   Token '응답' added similar words: ['음압', '악습', '융합', '오답']
#   Token '소지품' added similar words: ['소모품', '수리점', '사치품']
#   Token '과제' added similar words: ['교제', '.과제', '그제', '규제']
#   Token '부주의' added similar words: ['부업', '분업', '불의', '불룩', '부워서']
#   Token '조직' added similar words: ['지목', '지적', '정직']
#   Token '요소' added similar words: ['요로', '염소', '여고', '의사']
#   Token '휴대' added similar words: ['휴게', '해체', '유대', '확대']
#   Token '임무' added similar words: ['입주', '인품', '음미', '일부']
#   Token '작업' added similar words: ['잔업', '적합', '정답']
#   Token '포함' added similar words: ['모함', '보람', '호감', '참혹']
#   Token '마감일' added similar words: ['만기일', '모바일', '말조심']
#   Token '장시간' added similar words: ['지사장']
#   Token '놀이' added similar words: ['내일', '네일', '논리', '노인']
#   Token '서류' added similar words: ['.서류', '슈퍼', '석류', '섬유']
#   Token '간과' added similar words: ['가관', '강화', '과장', '강좌']
#   Token '지갑' added similar words: ['자립', '지급', '진급', '접시']
#   Token '연필' added similar words: ['연일', '인출', '언질', '어필']
#   Token '작성' added similar words: ['작정', '정작']
#   Token '부정확' added similar words: ['부정맥', '부재중', '부정부패', '분별력']
#   Token '물품' added similar words: ['물불', '물음', '물주', '물거품']
#   Token '여가' added similar words: ['여자', '연가', '여사', '여간']
#   Token '독서' added similar words: ['독거', '동서', '독선', '도서']
#   Token '청소년' added similar words: ['청소년과', '청소기', '평행선', '청소년기']
#   Token '학교' added similar words: ['학과', '후각', '합격', '.하교']
#   Token '노력' added similar words: ['노령', '녹초', '조력', '녹차']
#   Token '불안정' added similar words: ['불장난', '분만실', '불안감', '본부장', '부반장']
#   Token '일상' added similar words: ['일생', '일당']
#   Token '준수' added similar words: ['전수', '주선', '주문', '주전']
#   Token '교실' added similar words: ['과실', '거실', '괄시', '기술']
#   Token '무단' added similar words: ['만두', '무당', '무한', '문자']
#   Token '부족' added similar words: ['부속', '복구', '부조', '복수']
#   Token '완료' added similar words: ['연체', '연희', '연휴']
#   Token '의무' added similar words: ['유무', '의수']
#   Token '참여' added similar words: ['창의', '참견', '차용', '차주']
#   Token '문서' added similar words: ['무선', '무언', '문건', '문구']
#   Token '안절부절' added similar words: ['애물단지', '애완동물', '오매불망', '왈가왈부']
#   Token '건망증' added similar words: ['건강미', '건조증', '고주망태', '기면증']
#   Token '정돈' added similar words: ['전동', '정독', '진동']
#   Token '자리' added similar words: ['자치', '자비', '자기']
#   Token '업무' added similar words: ['요법']
#   Token '관리' added similar words: ['권리', '기관', '과신']
#   Token '물건' added similar words: ['물정', '물증', '문물']
#   Token '불편' added similar words: ['불평', '분별', '불륜', '분출']
#   Token '점유' added similar words: ['저염', '점퍼', '주범', '점주', '저금']
#   Token '실수' added similar words: ['시술', '실시', '실무', '심술']
#   Token '도구' added similar words: ['도주', '도수', '도우', '도모']
#   Token '부적절' added similar words: ['별문제', '증거물']
#   Token '집중' added similar words: ['중지', '중립', '중기', '징후']
#   Token '강의' added similar words: ['강요', '감원', '고용']
#   Token '재료' added similar words: ['재화', '제재', '재배', '재무']
#   Token '무질서' added similar words: ['미지수', '무심결', '물고기', '메신저', '밀가루']
#   Token '제한' added similar words: ['젠가', '제안', '재학', '지하']
#   Token '유지' added similar words: ['유기', '유치', '유리']
#   Token '전화' added similar words: ['전혀', '전환', '전과']
#   Token '숙제' added similar words: ['세력', '수백', '수확']
#   Token '요구' added similar words: ['여부']
#   Token '검토' added similar words: ['검소', '금고', '그놈']
#   Token '안경' added similar words: ['연장', '연상', '영란']
#   Token '대화' added similar words: ['대체', '대세', '대부', '화해']
#   Token '심부름' added similar words: ['시금치', '시스템']
#   Token '어려움' added similar words: ['원룸', '여름철', '음료수']
#   Token '보고서' added similar words: ['보건소', '보호사', '소견서', '보호소']
#   Token '지불' added similar words: ['지출', '진출', '질투', '줄기']
#   Token '질문' added similar words: ['지문', '주민', '절친']
#   Token '청구서' added similar words: ['천성', '추천서', '충전']
#   Token '사무실' added similar words: ['시말서', '실무자', '살며시', '술자리']
#   Token '공부' added similar words: ['고충', '공주', '곤충', '공수']
#   Token '집안일' added similar words: ['주일날', '바이올린', '차일피일']
#   Token '경우' added similar words: ['구연', '구경', '구역', '구성']
#   Token '지시' added similar words: ['지기', '지지', '.지시', '직시']
#   Token '게임' added similar words: ['게이머', '기름', '기금', '근심']
#   Token '순차' added similar words: ['사천', '상추', '사만', '수단', '산후']
#   Token '직장' added similar words: ['직종', '지장', '직성', '장식']
#   Token '허락' added similar words: ['하락', '흑자', '휴학']
#   Token '충분히' added similar words: ['친구분', '출입문', '친부모']
#   Token '필요' added similar words: ['풀이', '필기', '필히', '피규어']
#   Token '마음' added similar words: ['다음', '마감', '말씀', '발음']
#   Token '대답' added similar words: ['해답', '담대', '대담', '대주다']
#   Token '가만히' added similar words: ['간절히', '개망신', '간단히']
#   Token '휴대폰' added similar words: ['헤드폰', '피드백', '팬데믹']
#   Token '마감 기한' added similar words: ['만족감', '안간힘', '친근감']
#   Token '식당' added similar words: ['식단', '시동']
#   Token '자주' added similar words: ['주자', '자구', '주가', '주차']
#   Token '참가' added similar words: ['차감', '첨가', '차남']
#   Token '수정' added similar words: ['수중', '수전', '수령']
#   Token '핸드폰' added similar words: ['현대판', '사모펀드']
#   Token '휴대전화' added similar words: ['핸드백', '데면데면', '헤드헌터', '환급금']
#   Token '종종' added similar words: ['조종', '종강', '동종']
# Disorder: bipolar_disorder
#   Token '과대' added similar words: ['교대', '개그', '교재', '교내']
#   Token '자존감' added similar words: ['자신감', '자존심', '존재감', '장난감']
#   Token '과대망상' added similar words: ['강박증', '갑상샘', '가정불화']
#   Token '구매' added similar words: ['구내', '구애', '구백', '개수']
#   Token '에너지' added similar words: ['어머니', '어거지', '언제나']
#   Token '관여' added similar words: ['과언', '견과']
#   Token '증가' added similar words: ['장가', '장르', '장마', '자궁']
#   Token '흥분' added similar words: ['희망', '환승', '명분']
#   Token '아이디어' added similar words: ['어린아이', '아이러니', '다이어리', '에이치디']
#   Token '투자' added similar words: ['투잡', '타자', '투찰']
#   Token '수면' added similar words: ['수년', '수명', '서문']
#   Token '관찰' added similar words: ['경찰', '가출', '결판', '각별']
#   Token '욕구' added similar words: ['용무']
#   Token '사업' added similar words: ['산업', '서랍', '사법', '사유서']
#   Token '동요' added similar words: ['동원']
#   Token '운동' added similar words: ['용돈', '이동', '온통', '임종']
#   Token '확장' added similar words: ['환장', '황망', '화장', '환상']
#   Token '쇼핑' added similar words: ['서핑', '시늉', '시청']
#   Token '보고' added similar words: ['보조', '보모', '보호']
#   Token '경주' added similar words: ['격주']
#   Token '결과' added similar words: ['과열', '결제', '경과']
#   Token '무분별' added similar words: ['문교부', '두문불출', '두루뭉술']
#   Token '거의' added similar words: ['개의', '건의', '급여', '교우']
#   Token '매일' added similar words: ['메일', '매실', '만일', '막일']
#   Token '가능' added similar words: ['강릉', '그간']
#   Token '주관' added similar words: ['주변']
#   Token '적어도' added similar words: ['중요도', '지도력', '작년도']
#   Token '평소' added similar words: ['청소', '포상', '평생']
#   Token '너무' added similar words: ['누구', '너와']
#   Token '비정상' added similar words: ['시궁창', '보신탕', '신장병', '성장기', '신경증']
#   Token '비행' added similar words: ['보행', '비방', '백지', '이행']
#   Token '거만' added similar words: ['그만', '교만', '가만', '가전']
#   Token '압박감' added similar words: ['아침밥', '안도감', '유방암', '음악가']
#   Token '평가' added similar words: ['파견', '병가', '병자']
# Disorder: avoidant_personality_disorder
#   Token '거절' added similar words: ['구절', '거덜', '구걸', '걸레']
#   Token '대인' added similar words: ['대신', '단지', '단기']
#   Token '불승인' added similar words: ['불신감', '흡연실', '비상근무', '볼멘소리']
#   Token '조롱' added similar words: ['종로', '조정', '종목']
#   Token '걱정' added similar words: ['국정', '긍정', '견적']
#   Token '일관' added similar words: ['일환', '일군', '이관', '일과']
#   Token '반대' added similar words: ['박대', '배란', '배반']
#   Token '과민증' added similar words: ['관광지', '금지령']
#   Token '열등감' added similar words: ['암병동', '열흘간', '얼만큼', '월급날']
#   Token '비판' added similar words: ['비만', '비난', '빈칸']
#   Token '친밀' added similar words: ['치질', '친절']
#   Token '감수' added similar words: ['검사', '가수']
#   Token '자제' added similar words: ['제자', '자네', '자재', '자체']
#   Token '열등' added similar words: ['월등', '얼릉', '염증', '월경']
#   Token '당혹' added similar words: ['동학', '독학', '단속', '통학']
#   Token '패턴' added similar words: ['플랜', '편애', '팽배']
#   Token '확신' added similar words: ['형식', '현직']
#   Token '무능' added similar words: ['무청', '무용', '맹구']
#   Token '당황' added similar words: ['등장', '동창']
#   Token '자제력' added similar words: ['제작', '제자리', '잠적', '전락']
#   Token '접촉' added similar words: ['접목', '접속', '제목']
#   Token '상당' added similar words: ['성당', '상장', '상승']
#   Token '매력' added similar words: ['맥주', '무력', '매년', '무척']
#   Token '수치심' added similar words: ['시기심']
#   Token '거부' added similar words: ['거주', '과부']
# Disorder: MDD(major_depressive_disorder)
#   Token '활력' added similar words: ['확률', '혈육', '환멸', '협력']
#   Token '관심' added similar words: ['결심', '과감히', '고심']
#   Token '손실' added similar words: ['손길', '소실', '성실']
#   Token '재해' added similar words: ['재개']
#   Token '현저히' added similar words: ['여전히', '완전히', '환절기']
#   Token '수면과다증' added similar words: ['수행평가', '영문학과', '생물학과', '합병증', '황반변성']
#   Token '사별' added similar words: ['수발', '설마', '사물', '설사']
#   Token '우유부단' added similar words: ['아주버님', '아부의 왕', '운동부', '우두커니']
#   Token '과다수면증' added similar words: ['간접흡연', '갑상선염', '간경변증']
#   Token '종일' added similar words: ['통일', '동일', '당일']
#   Token '반추' added similar words: ['반주', '부착', '부자', '반문']
#   Token '재정' added similar words: ['전쟁', '제정', '중재', '재건']
#   Token '무가치감' added similar words: ['마음가짐', '몸가짐', '무임승차', '하루아침']
#   Token '절망감' added similar words: ['정말로', '졸업반', '중압감', '단절감']
#   Token '저하' added similar words: ['자해', '저가', '자처', '자초']
#   Token '슬픔' added similar words: ['슬럼프', '스팸', '스켈', '스케줄']
#   Token '체중' added similar words: ['체증', '체형', '축제', '추적']
#   Token '흥미' added similar words: ['혼미', '허망', '입증', '흡기']
#   Token '눈물' added similar words: ['눈병', '누설', '충분']
#   Token '자연' added similar words: ['자원', '조연', '장년', '작년']
#   Token '상실' added similar words: ['사실', '상술']
#   Token '절망' added similar words: ['정말', '전말', '전망']
#   Token '초조' added similar words: ['.초조', '초코', '초보']
#   Token '사고력' added similar words: ['성악', '속박']
#   Token '피로' added similar words: ['피포', '도리', '파리']
#   Token '구체' added similar words: ['구제']
#   Token '다이어트' added similar words: ['포인트', '바이러스', '카이스트']
#   Token '지체' added similar words: ['지레', '지네', '재치', '지게']
#   Token '망상' added similar words: ['막상', '항상', '명상', '막강']
#   Token '질병' added similar words: ['지병', '정밀']
#   Token '부진' added similar words: ['분기', '비중', '부친', '비문']
#   Token '식욕' added similar words: ['숙식', '식이', '수익', '식탁']
#   Token '파탄' added similar words: ['팔자', '파티', '판사', '파산']
#   Token '즐거움' added similar words: ['점원들', '전세금', '절제술']
#   Token '자살' added similar words: ['창살', '살살', '자질']
#   Token '수치감' added similar words: ['사무직', '수막염']
#   Token '자기혐오' added similar words: ['자기만족', '자격지심', '자린고비', '적임자']
#   Token '문제해결력' added similar words: ['커뮤니케이션', '컴퓨터활용능력', '무기력증', '대중목욕탕', '우황청심환']
#   Token '문제해결력과' added similar words: ['중증 근무력증', '연극영화과']
#   Token '원푸드' added similar words: ['요구르트', '월드컵', '유머러스', '요즈음', '여드름']
# Disorder: generalized_anxiety_disorder
#   Token '근육' added similar words: ['근력', '금액', '근원', '금연']
#   Token '신체' added similar words: ['시체', '신세']
#   Token '불만족' added similar words: ['불감증']
#   Token '며칠' added similar words: ['멸시', '멀미', '멀리']
#   Token '기대' added similar words: ['기재', '개미', '개시', '개심']
#   Token '긴장' added similar words: ['김장', '간장', '간직']
#   Token '통제' added similar words: ['통화', '통과', '태동', '토지']
#   Token '얼마' added similar words: ['엄마', '업자']
# Disorder: seperation_anxiety_disorder
#   Token '별거' added similar words: ['별개', '벼슬', '별루']
#   Token '대상' added similar words: ['대강', '대장', '대항', '달성']
#   Token '애착' added similar words: ['액자', '아재', '악착', '오백']
#   Token '이별' added similar words: ['이불', '열기', '이율']
#   Token '공포증' added similar words: ['공포감', '공모전', '공동체', '공통점']
#   Token '혼자' added similar words: ['혼사', '한자', '한정', '한잔']
#   Token '두통' added similar words: ['도통', '도중', '봉투', '동무']
#   Token '사망' added similar words: ['상가']
#   Token '피해' added similar words: ['패기', '패치', '펀치']
#   Token '근처' added similar words: ['근래']
#   Token '재난' added similar words: ['재단', '재판']
#   Token '악몽' added similar words: ['억장', '엉망', '옥상', '복장']
#   Token '동반자' added similar words: ['당분간', '단톡방', '단속반', '당당히']
#   Token '주제' added similar words: ['주체', '주저', '저주', '재주']
#   Token '환경' added similar words: ['현황', '현관', '현명', '환영']
#   Token '환각' added similar words: ['한국', '확산', '학군', '행각']
#   Token '광장' added similar words: ['관장', '권장', '강경', '궁상', '국장']
#   Token '발달' added similar words: ['발설', '반말', '박탈', '반발']
#   Token '구토' added similar words: ['국토', '구조', '구타']
#   Token '악화' added similar words: ['안과']
#   Token '우려' added similar words: ['여주', '여우', '염려']
#   Token '납치' added similar words: ['납기', '나비', '눈치', '남편']
#   Token '호소' added similar words: ['호사', '속도', '해소']
#   Token '복통' added similar words: ['복종', '보통']
#   Token '홀로' added similar words: ['홀수', '볼모', '솔로']
#   Token '핵심' added similar words: ['막심', '합심', '해임']
# Disorder: neurocognitive_disorders
#   Token '치매' added similar words: ['.치매', '채집']
#   Token '섬망' added similar words: ['삼만', '삼성', '상품', '상금', '서방']
#   Token '알츠하이머' added similar words: ['아르바이트', '아르바이르', '살얼음판', '임플란트']
#   Token '울증' added similar words: ['열중', '엄중']
#
# time: 27min 33s (started: 2024-06-12 18:29:28 +00:00)

# %%
# Out:
# time: 27min 33s (started: 2024-06-12 18:29:28 +00:00)
