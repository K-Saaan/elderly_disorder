# %%
from gensim.models import KeyedVectors
from util.viz import tsne_plot, tsne_plot_similar_words
import warnings
warnings.filterwarnings('ignore')

model = KeyedVectors.load_word2vec_format("eng_w2v")

# %%
tsne_plot(model, dimensions=2, n_words=300)

# %%
tsne_plot(model, dimensions=3, n_words=500)

# %%
tsne_plot_similar_words(model, ['book', 'cup', 'dog'], 2)

# %%
tsne_plot_similar_words(model, ['book', 'cup', 'dog'], dimensions=3, top_n=30)
